# %%
import pandas as pd

# %%
df=pd.read_csv("Facebook.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0           0            139441   Photo         2          12             4
# 1           1            139441  Status         2          12             3
# 2           2            139441   Photo         3          12             3
# 3           3            139441   Photo         2          12             2
# 4           4            139441   Photo         2          12             2
#
#    Post Hour  Paid  Lifetime Post Total Reach  \
# 0          3   0.0                       2752
# 1         10   0.0                      10460
# 2          3   0.0                       2413
# 3         10   1.0                      50128
# 4          3   0.0                       7244
#
#    Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                             5091                     178
# 1                            19057                    1457
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Unnamed: 0                                                           500 non-null    int64
#  1   Page total likes                                                     500 non-null    int64
#  2   Type                                                                 500 non-null    object
#  3   Category                                                             500 non-null    int64
#  4   Post Month                                                           500 non-null    int64
#  5   Post Weekday                                                         500 non-null    int64
#  6   Post Hour                                                            500 non-null    int64
# ...

# %%
df.shape
# Out:
# (500, 20)

# %%
df_subset1 = df[['like','share']]

# %%
df_subset1
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
df_subset2 = df[['comment','Type']]

# %%
df_subset2
# Out:
#      comment    Type
# 0          4   Photo
# 1          5  Status
# 2          0   Photo
# 3         58   Photo
# 4         19   Photo
# ..       ...     ...
# 495        5   Photo
# 496        0   Photo
# 497        4   Photo
# 498        7   Photo
# 499        0   Photo
#
# [500 rows x 2 columns]

# %%
merged_data = pd.merge(df_subset2, df_subset1, left_on='comment',right_on='like')
merged_data
# Out:
#       comment    Type  like  share
# 0           4   Photo   4.0    2.0
# 1           4   Photo   4.0    1.0
# 2           4   Photo   4.0    0.0
# 3           4   Photo   4.0    1.0
# 4           5  Status   5.0    2.0
# ...       ...     ...   ...    ...
# 1462        0   Photo   0.0    0.0
# 1463        0   Photo   0.0    0.0
# 1464        0   Photo   0.0    0.0
# 1465        0   Photo   0.0    0.0
# 1466        0   Photo   0.0    0.0
#
# [1467 rows x 4 columns]

# %%
sorted_df = df.sort_values(by='like', ascending=False)
print("\nSorted Data by Likes (Descending):")
print(sorted_df)
# Out:
# Sorted Data by Likes (Descending):
#      Unnamed: 0  Page total likes   Type  Category  Post Month  Post Weekday  \
# 244         244            130791  Photo         2           7             3
# 379         379            111620  Photo         3           4             1
# 349         349            117764  Photo         3           5             5
# 168         168            135428  Photo         1           9             3
# 3             3            139441  Photo         2          12             2
# ..          ...               ...    ...       ...         ...           ...
# 100         100            137020  Photo         1          10             4
# 417         417            104070  Photo         1           3             3
# 441         441             98195  Photo         1           3             5
# 21           21            138414  Photo         1          12             7
# 111         111            136736  Photo         1          10             6
#
# ...

# %%
merged_data.transpose()
# Out:
#           0      1      2      3       4      5      6      7      8     \
# comment      4      4      4      4       5      0      0      0      0
# Type     Photo  Photo  Photo  Photo  Status  Photo  Photo  Photo  Photo
# like       4.0    4.0    4.0    4.0     5.0    0.0    0.0    0.0    0.0
# share      2.0    1.0    0.0    1.0     2.0    0.0    0.0    0.0    0.0
#
#           9     ...   1457   1458   1459   1460   1461   1462   1463   1464  \
# comment      0  ...      7      7      7      7      7      0      0      0
# Type     Photo  ...  Photo  Photo  Photo  Photo  Photo  Photo  Photo  Photo
# like       0.0  ...    7.0    7.0    7.0    7.0    7.0    0.0    0.0    0.0
# share      0.0  ...    2.0    NaN    2.0    3.0    2.0    0.0    0.0    0.0
#
#           1465   1466
# comment      0      0
# Type     Photo  Photo
# like       0.0    0.0
# share      0.0    0.0
#
# [4 rows x 1467 columns]

# %%
merged_data.T
# Out:
#           0      1      2      3       4      5      6      7      8     \
# comment      4      4      4      4       5      0      0      0      0
# Type     Photo  Photo  Photo  Photo  Status  Photo  Photo  Photo  Photo
# like       4.0    4.0    4.0    4.0     5.0    0.0    0.0    0.0    0.0
# share      2.0    1.0    0.0    1.0     2.0    0.0    0.0    0.0    0.0
#
#           9     ...   1457   1458   1459   1460   1461   1462   1463   1464  \
# comment      0  ...      7      7      7      7      7      0      0      0
# Type     Photo  ...  Photo  Photo  Photo  Photo  Photo  Photo  Photo  Photo
# like       0.0  ...    7.0    7.0    7.0    7.0    7.0    0.0    0.0    0.0
# share      0.0  ...    2.0    NaN    2.0    3.0    2.0    0.0    0.0    0.0
#
#           1465   1466
# comment      0      0
# Type     Photo  Photo
# like       0.0    0.0
# share      0.0    0.0
#
# [4 rows x 1467 columns]

# %%
df.shape
# Out:
# (500, 20)

# %%
df_temp = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
'baz': [1, 2, 3, 4, 5, 6],
'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df_temp
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    threshold = 1.5 * IQR
    outlier_mask = (column < Q1 - threshold) | (column > Q3 + threshold)
    return column[~outlier_mask]

# %%
df = df.drop_duplicates()

# %%
col_name = ['Category','Post Month','Post Weekday','Post Hour','Paid']
for col in col_name:
    df[col] = remove_outliers(df[col])

# %%
df.columns = df.columns.str.strip()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x="Type", palette="coolwarm")
plt.title("Distribution of Post Types")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Harshvardhan\AppData\Local\Temp\ipykernel_24144\2597789548.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Type", palette="coolwarm")

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="Post Month", y="Lifetime Post Total Reach", marker="o", label="Total Reach")
sns.lineplot(data=df, x="Post Month", y="Lifetime Post Total Impressions", marker="s", label="Total Impressions")
plt.title("Monthly Trend of Post Reach & Impressions")
plt.xlabel("Month")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Lifetime Post Total Reach"], bins=20, kde=True, color="blue")
plt.title("Distribution of Post Reach")
plt.xlabel("Lifetime Post Total Reach")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Lifetime Post Total Impressions", y="Lifetime Engaged Users", hue="Type", alpha=0.7)
plt.title("Engagement vs. Impressions")
plt.xlabel("Total Impressions")
plt.ylabel("Engaged Users")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="Type", y="Total Interactions", palette="pastel")
plt.title("Total Interactions per Post Type")
plt.xlabel("Post Type")
plt.ylabel("Total Interactions")
plt.show()
# Out:
# C:\Users\Harshvardhan\AppData\Local\Temp\ipykernel_24144\1378177151.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Type", y="Total Interactions", palette="pastel")

# %%
reshaped_df = df.pivot_table(index='Type', columns='Category', values='like', aggfunc='mean')
print("\nReshaped Data using Pivot Table:\n", reshaped_df)
# Out:
# Reshaped Data using Pivot Table:
#  Category           1           2           3
# Type
# Link       75.650000   32.000000   68.000000
# Photo     126.000000  235.857143  219.753333
# Status    136.333333  182.552632  151.500000
# Video     231.428571         NaN         NaN

# %%
melted_df = df.melt(id_vars='Type', value_vars=['like', 'share'], var_name='Metric', value_name='Value')
print("\nReshaped Data using Melt:\n", melted_df.head())
# Out:
# Reshaped Data using Melt:
#       Type Metric   Value
# 0   Photo   like    79.0
# 1  Status   like   130.0
# 2   Photo   like    66.0
# 3   Photo   like  1572.0
# 4   Photo   like   325.0
